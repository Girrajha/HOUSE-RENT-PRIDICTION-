# %% [markdown]
# # House Price linear regression Project

# %% [markdown]
# 1 LIBRAATIRS IMPORT
#
# 2 DATA GATHERING
#
# 3 EDA
#
# 4 ASSUMPTION

# %%
by using House data we train linear regression and try to predict new outcome
# Out:
#   File "<ipython-input-4-1880760739>", line 1
#     by using House data we train linear regression and try to predict new outcome
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 1. Problem statement

# %%
by using House data we train linear regression and try to predict new outcome
# Out:
#   File "<ipython-input-5-1880760739>", line 1
#     by using House data we train linear regression and try to predict new outcome
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 2. Libreries import

# %%
import pandas as pd
import numpy as np

# visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Linear regression import
from sklearn.linear_model import LinearRegression

# train-test-split
from sklearn.model_selection import train_test_split

# evaluation metrics
from sklearn.metrics  import r2_score, mean_squared_error

# vif (no multicolinearity)
from statsmodels.stats.outliers_influence import variance_inflation_factor

# scipy.stats as stats
import scipy.stats as stats    # if we want any statistic model that time we can aslo use scipy.stats or your can use numpy stats function

# %%
sklearn >> sckit-learn
linear_model   >> LinearRegression, LogisticRegression

100%  (1000)      # model_selection
training = 80 - 800   # r^2 >>
testing  = 20 - 200

evaluation metrics
best fit line
mse  >> mean_squared_error   ()
r_squared
rmse

# %% [markdown]
# # 3. Data Gathering

# %%
# load the csv data by using pandas
#/housing_5000.csv
# y = 'price'                       # dependent column
# x = ['area','bedrooms', 'age']    # independent columns

df = pd.read_csv("/housing_5000.csv")
df.head()
# Out:
#    area  bedrooms  age   price
# 0  1660         1   29  262054
# 1  4572         5   27  705629
# 2  3892         4   30  586737
# 3  1266         1   25  178622
# 4  4244         4   42  649809

# %% [markdown]
# # 4. EDA

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.isnull().sum()
# Out:
# area        0
# bedrooms    0
# age         0
# price       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   area      5000 non-null   int64
#  1   bedrooms  5000 non-null   int64
#  2   age       5000 non-null   int64
#  3   price     5000 non-null   int64
# dtypes: int64(4)
# memory usage: 156.4 KB

# %% [markdown]
# # 5. assumption

# %%
# assumption1 linearity ( feature vs target linearily correlated)

features = ['area','bedrooms', 'age']

for i in features:
    sns.scatterplot(x=df[i], y=df['price'])
    plt.title(f"{i} vs Pride")
    plt.show()

# %%
df.corr()              # r value
# Out:
#               area  bedrooms       age     price
# area      1.000000 -0.003070 -0.011044  0.990157
# bedrooms -0.003070  1.000000  0.005294  0.074168
# age      -0.011044  0.005294  1.000000 -0.050986
# price     0.990157  0.074168 -0.050986  1.000000

# %%
df['area'].corr(df['price'])

# r value is 0.999
r>0.7
# area and price have strong correlation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-1300233601> in <cell line: 0>()
#       2
#       3 # r value is 0.999
# ----> 4 r>0.7
#       5 # area and price have strong correlation
#
# NameError: name 'r' is not defined

# %%
df['bedrooms'].corr(df['price'])
# r values is 0.07
# it is not good
# Out:
# np.float64(0.0741680713785027)

# %%
df['age'].corr(df['price'])
# r vlaues is not good
# Out:
# np.float64(-0.05098634047456018)

# %%
# 2. no multicoliearity

features = ['area','bedrooms', 'age']
vif = 1    >> no correlation
vif = 5    >> moderate correlation
vif = 10   >> highly correlation between 2 or more independent variable
# Out:
#   File "<ipython-input-22-3810878138>", line 4
#     vif = 1    >> no correlation
#                      ^
# SyntaxError: invalid syntax

# %%
features = ['area','bedrooms', 'age']
x_temp = df[features]         # we create data frame
vif_data = pd.DataFrame()

vif_data['features'] = x_temp.columns
vif_data
# Out:
#    features
# 0      area
# 1  bedrooms
# 2       age

# %%
features = ['area','bedrooms', 'age']
x_temp = df[features]
vif_data = pd.DataFrame()
vif_data['features'] = x_temp.columns

vif=[variance_inflation_factor(x_temp.values, i) for i in range(0,x_temp.shape[1])]
vif_data["vif"] = vif

# %%
vif_data

# %%
x_temp.shape[1]
# Out:
# 3

# %%
(5000, 3)
# Out:
# (5000, 3)

# %%
features = ['area','bedrooms', 'age']
x_temp = df[features]
vif_data = pd.DataFrame()
vif_data['features'] = x_temp.columns

vif=[variance_inflation_factor(x_temp.values, i) for i in range(0,3)]
vif_data["vif"] = vif

# %%
vif_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3561650553> in <cell line: 0>()
# ----> 1 vif_data
#
# NameError: name 'vif_data' is not defined

# %% [markdown]
# TRAIN TEST SPLIT

# %%
x = df[["area","bedrooms","age"]] # 80 train 20 teste
y = df["price"]    # 80 train 20 test

# %%
x

# %%
y

# %%
100
test_size = 0.2  20%
x =t_train , x_test
y = t_train , y_test
random_state= 42 (true ) between 1,99
# Out:
#   File "<ipython-input-29-4220587328>", line 2
#     test_size = 0.2  20%
#                      ^
# SyntaxError: invalid syntax

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-1710797709> in <cell line: 0>()
# ----> 1 x_train
#
# NameError: name 'x_train' is not defined

# %%
x_test
# Out:
#       area  bedrooms  age
# 1501  2833         2   45
# 2586  2663         1   22
# 2653  3142         4   26
# 1055  1414         3   16
# 705    809         5   10
# ...    ...       ...  ...
# 4711  1278         4   24
# 2313  2099         2   43
# 3214  4142         2   10
# 2732  4037         4   22
# 1926  1446         4   18
#
# [1000 rows x 3 columns]

# %% [markdown]
# TRAIN MODEL

# %% [markdown]
# fit >> we just store data or we give data fir traing

# %%
# TRAIN THE MODEL

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_train)
y_pred
# Out:
# array([731087.16091403, 275013.3363762 , 547663.2113464 , ...,
#        181291.93807519, 566698.58550591, 477607.6562504 ])

# %% [markdown]
# for train data

# %% [markdown]
# calculate acc of model(R^2 value )  --> value above 0.8 is acceptable

# %%
accuracy_train = r2_score(y_train, y_pred)
accuracy_train
# Out:
# 0.9879649042128996

# %%
mse = mean_squared_error(y_train, y_pred)
mse
# Out:
# 401901641.9119612

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(20047.48467793307)

# %% [markdown]
# MODEL TESTING

# %%
y_pred_test = model.predict(x_test)
y_pred_test
# Out:
# array([422207.52799124, 398617.15184052, 498081.86285678, 233852.76414599,
#        165799.54119665, 651345.7664126 , 746929.64011845, 530831.09978252,
#        530706.98115986, 528779.76502339, 155600.87350877, 660431.03416243,
#        595681.7815976 , 317173.97564876, 252024.06113814, 676612.22130434,
#        602601.94423297, 474041.52512616, 368020.00922909, 254088.46610175,
#        750859.77168109, 608383.67905792, 298026.2947146 , 217622.04513454,
#        505702.80043463, 707459.79922306, 474040.96885786, 596420.39537028,
#        287702.39586747, 698650.0216641 , 634112.46364586, 459337.53313648,
#        486543.45347234, 718759.58514823, 289404.76083732, 609559.62166566,
#        620346.49289283, 369646.8207291 , 239809.28901096, 402622.39941336,
#        385515.1487027 , 547625.75595341, 318775.96450061, 532445.74839044,
#        436524.16047503, 743551.83909143, 218886.31977682, 366993.12670083,
#        516627.59497022, 625640.4597008 , 300454.78653216, 168239.69904234,
#        557162.59468369, 404511.8955283 , 330038.00339303, 137554.60245167,
#        412621.07097588, 703630.92407955, 730875.00189658, 644324.69840218,
#        331277.8928468 , 411644.71404509, 375090.84134448, 402096.47391522,
#        141596.95437342, 352576.40973881, 504063.18335868, 502223.8023928 ,
#        370046.75357549, 200189.01087097, 634951.24831232, 647429.05609852,
#        491536.31355568, 327761.11537911, 720024.00561039, 615190.65461748,
#        203004.62995898, 319801.46986375, 572942.32599421, 381660.48419433,
#        621223.05698514, 499195.46801903, 674396.61760364, 658804.71952639,
#        467634.36360434, 142673.19055823, 474817.62130305, 682055.27520302,
#        692567.00728341, 285036.3337229 , 676260.99943066, 640845.64095602,
#        257155.36840509, 205145.26346937, 688049.25546098, 221376.06889638,
#        676035.7108044 , 295837.50649979, 238996.08848516, 353015.67200728,
#        553782.77380771, 174409.99232532, 226218.84277921, 664071.81144413,
#        306373.00809608, 684071.17441813, 745866.88458652, 670279.82474864,
#        558425.96201359, 738432.81352523, 672970.41790161, 296624.77184084,
#        665210.91433149, 582128.79075885, 181329.74451227, 558188.71571944,
#        605643.05717145, 326009.42376393, 763235.97200406, 629369.97946547,
#        723127.92584709, 304772.45581367, 326721.9835432 , 279243.46212689,
#        656838.84904478, 651145.35983883, 331854.05230266, 422620.85507497,
#        538240.49401554, 192043.08211857, 467058.6145969 , 370523.06078855,
#        418102.34176005, 609222.46372438, 746266.81743292, 586095.32458224,
#        180241.90170365, 493913.92873169, 637492.3709374 , 219186.22754931,
#        313006.94883605, 636740.6005447 , 634538.59630554, 247493.59015532])

# %%
accuracy_test = r2_score(y_test, y_pred_test)
accuracy_test
# Out:
# 0.9881649565155366

# %%
mse_test = mean_squared_error(y_test, y_pred_test)
mse_test
# Out:
# 398100103.67941445

# %%
rmse_test = np.sqrt(mse_test)
rmse_test
# Out:
# np.float64(19952.446057549296)

# %% [markdown]
#   OVERFITTING AND UNDERFITTING

# %%
 train = 0.987
 test = 0.688

# %% [markdown]
# try to pridict on new data

# %%
new_data= pd.DataFrame([[3000,3,10]], columns = features)
new_data
# Out:
#    area  bedrooms  age
# 0  3000         3   10

# %%
prediction = model.predict(new_data)
prediction
# Out:
# array([475104.8963307])
